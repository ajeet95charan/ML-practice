# %%
import pandas as pd

# %%
dataset = pd.read_csv('wines.csv')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Class                         178 non-null    int64
#  1   Alcohol                       178 non-null    float64
#  2   Malic_acid                    178 non-null    float64
#  3   Ash                           178 non-null    float64
#  4   Alcalinity_of_ash             178 non-null    float64
#  5   Magnesium                     178 non-null    int64
#  6   Total_phenols                 178 non-null    float64
#  7   Flavanoids                    178 non-null    float64
#  8   Nonflavanoid_phenols          178 non-null    float64
#  9   Proanthocyanins               178 non-null    float64
#  10  Color_intensity               178 non-null    float64
#  11  Hue                           178 non-null    float64
#  12  OD280-OD315_of_diluted_wines  178 non-null    float64
#  13  Proline                       178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
dataset.head()
# Out:
#    Class  Alcohol  Malic_acid   Ash  Alcalinity_of_ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    Total_phenols  Flavanoids  Nonflavanoid_phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color_intensity   Hue  OD280-OD315_of_diluted_wines  Proline
# 0             5.64  1.04                          3.92     1065
# 1             4.38  1.05                          3.40     1050
# 2             5.68  1.03                          3.17     1185
# 3             7.80  0.86                          3.45     1480
# 4             4.32  1.04                          2.93      735

# %%
y = dataset['Class']

# %%
y.value_counts()
# Out:
# 2    71
# 1    59
# 3    48
# Name: Class, dtype: int64

# %%
y = pd.get_dummies(y)

# %%
y
# Out:
#      1  2  3
# 0    1  0  0
# 1    1  0  0
# 2    1  0  0
# 3    1  0  0
# 4    1  0  0
# ..  .. .. ..
# 173  0  0  1
# 174  0  0  1
# 175  0  0  1
# 176  0  0  1
# 177  0  0  1
#
# [178 rows x 3 columns]

# %%
dataset.columns
# Out:
# Index(['Class', 'Alcohol', 'Malic_acid', 'Ash', 'Alcalinity_of_ash',
#        'Magnesium', 'Total_phenols', 'Flavanoids', 'Nonflavanoid_phenols',
#        'Proanthocyanins', 'Color_intensity', 'Hue',
#        'OD280-OD315_of_diluted_wines', 'Proline'],
#       dtype='object')

# %%
x = dataset.drop('Class', axis=1)

# %%
x
# Out:
#      Alcohol  Malic_acid   Ash  Alcalinity_of_ash  Magnesium  Total_phenols  \
# 0      14.23        1.71  2.43               15.6        127           2.80
# 1      13.20        1.78  2.14               11.2        100           2.65
# 2      13.16        2.36  2.67               18.6        101           2.80
# 3      14.37        1.95  2.50               16.8        113           3.85
# 4      13.24        2.59  2.87               21.0        118           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5         95           1.68
# 174    13.40        3.91  2.48               23.0        102           1.80
# 175    13.27        4.28  2.26               20.0        120           1.59
# 176    13.17        2.59  2.37               20.0        120           1.65
# 177    14.13        4.10  2.74               24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_phenols  Proanthocyanins  Color_intensity   Hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      OD280-OD315_of_diluted_wines  Proline
# 0                            3.92     1065
# 1                            3.40     1050
# 2                            3.17     1185
# 3                            3.45     1480
# 4                            2.93      735
# ..                            ...      ...
# 173                          1.74      740
# 174                          1.56      750
# 175                          1.56      835
# 176                          1.62      840
# 177                          1.60      560
#
# [178 rows x 13 columns]

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Alcohol                       178 non-null    float64
#  1   Malic_acid                    178 non-null    float64
#  2   Ash                           178 non-null    float64
#  3   Alcalinity_of_ash             178 non-null    float64
#  4   Magnesium                     178 non-null    int64
#  5   Total_phenols                 178 non-null    float64
#  6   Flavanoids                    178 non-null    float64
#  7   Nonflavanoid_phenols          178 non-null    float64
#  8   Proanthocyanins               178 non-null    float64
#  9   Color_intensity               178 non-null    float64
#  10  Hue                           178 non-null    float64
#  11  OD280-OD315_of_diluted_wines  178 non-null    float64
#  12  Proline                       178 non-null    int64
# dtypes: float64(11), int64(2)
# memory usage: 18.2 KB

# %%
import seaborn as sns

# %%
sns.scatterplot(x='Alcohol', y='Class', data=dataset)
# Out:
# <AxesSubplot:xlabel='Alcohol', ylabel='Class'>

# %%
from keras.models import Sequential

# %%
model = Sequential()

# %%
from keras.layers import Dense

# %%
x.shape
# Out:
# (178, 13)

# %%
model.add(Dense(units=5, 
                input_shape=(13,), 
                activation='relu',
                 ))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 5)                 70
# =================================================================
# Total params: 70
# Trainable params: 70
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(Dense(units=8, 
                activation='relu', 
                ))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 5)                 70
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 48
# =================================================================
# Total params: 118
# Trainable params: 118
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(Dense(units=6, 
                activation='relu', 
                ))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 5)                 70
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 48
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 54
# =================================================================
# Total params: 172
# Trainable params: 172
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(Dense(units=3, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 5)                 70
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 48
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 54
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 21
# =================================================================
# Total params: 193
# Trainable params: 193
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.optimizers import Adam

# %%
model.compile(optimizer=Adam(learning_rate=0.01),  
              loss='categorical_crossentropy',
              metrics=['accuracy']
             )

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 5)                 70
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 48
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 54
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 21
# =================================================================
# Total params: 193
# Trainable params: 193
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x, y , epochs=100)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 0s 1ms/step - loss: 7.6767 - accuracy: 0.3315
# Epoch 2/100
# 6/6 [==============================] - 0s 2ms/step - loss: 2.4415 - accuracy: 0.2753
# Epoch 3/100
# 6/6 [==============================] - 0s 1ms/step - loss: 1.3017 - accuracy: 0.2640
# Epoch 4/100
# 6/6 [==============================] - 0s 2ms/step - loss: 1.2979 - accuracy: 0.2247
# Epoch 5/100
# 6/6 [==============================] - 0s 2ms/step - loss: 1.1724 - accuracy: 0.1067
# Epoch 6/100
# 6/6 [==============================] - 0s 2ms/step - loss: 1.1088 - accuracy: 0.3034
# Epoch 7/100
# 6/6 [==============================] - 0s 2ms/step - loss: 1.0979 - accuracy: 0.3989
# Epoch 8/100
# 6/6 [==============================] - 0s 2ms/step - loss: 1.0904 - accuracy: 0.3989
# Epoch 9/100
# 6/6 [==============================] - 0s 2ms/step - loss: 1.0890 - accuracy: 0.3989
# Epoch 10/100
# 6/6 [==============================] - 0s 2ms/step - loss: 1.0900 - accuracy: 0.3989
# Epoch 11/100
# 6/6 [==============================] - 0s 2ms/step - loss: 1.0888 - accuracy: 0.3989
# Epoch 12/100
# 6/6 [==============================] - 0s 2ms/step - loss: 1.0868 - accuracy: 0.3989
# Epoch 13/100
# 6/6 [==============================] - 0s 2ms/step - loss: 1.0855 - accuracy: 0.3989
# Epoch 14/100
# 6/6 [==============================] - 0s 2ms/step - loss: 1.0832 - accuracy: 0.3989
# Epoch 15/100
# 6/6 [==============================] - 0s 2ms/step - loss: 1.0787 - accuracy: 0.3989
# Epoch 16/100
# 6/6 [==============================] - 0s 2ms/step - loss: 1.0663 - accuracy: 0.3989
# Epoch 17/100
# 6/6 [==============================] - 0s 2ms/step - loss: 1.0531 - accuracy: 0.3989
# Epoch 18/100
# 6/6 [==============================] - 0s 2ms/step - loss: 1.0430 - accuracy: 0.3989
# Epoch 19/100
# 6/6 [==============================] - 0s 2ms/step - loss: 1.0278 - accuracy: 0.3989
# Epoch 20/100
# 6/6 [==============================] - 0s 2ms/step - loss: 1.0126 - accuracy: 0.3989
# Epoch 21/100
# 6/6 [==============================] - 0s 1ms/step - loss: 1.0013 - accuracy: 0.3989
# Epoch 22/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9893 - accuracy: 0.5674
# Epoch 23/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9781 - accuracy: 0.6404
# Epoch 24/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9651 - accuracy: 0.6180
# Epoch 25/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9534 - accuracy: 0.6180
# Epoch 26/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9406 - accuracy: 0.6573
# Epoch 27/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9234 - accuracy: 0.6629
# Epoch 28/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9095 - accuracy: 0.6404
# Epoch 29/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8933 - accuracy: 0.6517
# Epoch 30/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8788 - accuracy: 0.6517
# Epoch 31/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8675 - accuracy: 0.6461
# Epoch 32/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.8536 - accuracy: 0.6629
# Epoch 33/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8459 - accuracy: 0.6517
# Epoch 34/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8264 - accuracy: 0.6685
# Epoch 35/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8158 - accuracy: 0.6629
# Epoch 36/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8117 - accuracy: 0.6573
# Epoch 37/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.7990 - accuracy: 0.6573
# Epoch 38/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8101 - accuracy: 0.6404
# Epoch 39/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.7783 - accuracy: 0.6742
# Epoch 40/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.7799 - accuracy: 0.6517
# Epoch 41/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.7664 - accuracy: 0.6742
# Epoch 42/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.7537 - accuracy: 0.6573
# Epoch 43/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.7490 - accuracy: 0.6517
# Epoch 44/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.7436 - accuracy: 0.6629
# Epoch 45/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.7306 - accuracy: 0.6629
# Epoch 46/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.7249 - accuracy: 0.6685
# Epoch 47/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.7207 - accuracy: 0.6685
# Epoch 48/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.7138 - accuracy: 0.6629
# Epoch 49/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.7193 - accuracy: 0.6742
# Epoch 50/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.7067 - accuracy: 0.6685
# Epoch 51/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.7058 - accuracy: 0.6629
# Epoch 52/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6964 - accuracy: 0.6685
# Epoch 53/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6919 - accuracy: 0.6685
# Epoch 54/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6920 - accuracy: 0.6685
# Epoch 55/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6882 - accuracy: 0.6685
# Epoch 56/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6778 - accuracy: 0.6742
# Epoch 57/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6771 - accuracy: 0.6685
# Epoch 58/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.7368 - accuracy: 0.6461
# Epoch 59/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.7334 - accuracy: 0.6517
# Epoch 60/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.7086 - accuracy: 0.6629
# Epoch 61/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6592 - accuracy: 0.6629
# Epoch 62/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6764 - accuracy: 0.6742
# Epoch 63/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6815 - accuracy: 0.6517
# Epoch 64/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6564 - accuracy: 0.6629
# Epoch 65/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6651 - accuracy: 0.6685
# Epoch 66/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6894 - accuracy: 0.6742
# Epoch 67/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6561 - accuracy: 0.6685
# Epoch 68/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6521 - accuracy: 0.6629
# Epoch 69/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6671 - accuracy: 0.6742
# Epoch 70/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6493 - accuracy: 0.6742
# Epoch 71/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6568 - accuracy: 0.6629
# Epoch 72/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6467 - accuracy: 0.6742
# Epoch 73/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6612 - accuracy: 0.6461
# Epoch 74/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6992 - accuracy: 0.6742
# Epoch 75/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6974 - accuracy: 0.6517
# Epoch 76/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.7233 - accuracy: 0.6517
# Epoch 77/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6330 - accuracy: 0.6742
# Epoch 78/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6317 - accuracy: 0.6742
# Epoch 79/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6576 - accuracy: 0.6742
# Epoch 80/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6253 - accuracy: 0.6854
# Epoch 81/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6406 - accuracy: 0.6685
# Epoch 82/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6593 - accuracy: 0.6685
# Epoch 83/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6618 - accuracy: 0.6742
# Epoch 84/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6479 - accuracy: 0.6798
# Epoch 85/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6326 - accuracy: 0.6629
# Epoch 86/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6595 - accuracy: 0.6517
# Epoch 87/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6251 - accuracy: 0.6854
# Epoch 88/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6359 - accuracy: 0.6573
# Epoch 89/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6507 - accuracy: 0.6742
# Epoch 90/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.7623 - accuracy: 0.6348
# Epoch 91/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6948 - accuracy: 0.6798
# Epoch 92/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6969 - accuracy: 0.6517
# Epoch 93/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6234 - accuracy: 0.6629
# Epoch 94/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6253 - accuracy: 0.6742
# Epoch 95/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6417 - accuracy: 0.6854
# Epoch 96/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6526 - accuracy: 0.6292
# Epoch 97/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6248 - accuracy: 0.6798
# Epoch 98/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6732 - accuracy: 0.6685
# Epoch 99/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6671 - accuracy: 0.6685
# Epoch 100/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.5900 - accuracy: 0.7135
